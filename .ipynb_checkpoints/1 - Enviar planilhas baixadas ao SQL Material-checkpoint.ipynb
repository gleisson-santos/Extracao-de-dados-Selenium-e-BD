# %%
#IMPORTAÇÃO DOS MODULOS E CHAMADA DAS TABELAS
import os
import pandas as pd
import glob
import pyodbc

path = r'C:\Users\gleisson.santos\Desktop\2 - Projetos Python\Projeto #1 - Automção SCIWEB\Projeto #6 - Extração de dados Selenium e BD\aa'
files = os.listdir(path)
df = pd.DataFrame()

for f in files_xls:
    data  = pd.read_html(f)
    data = data[1]
    data = data.dropna(axis=1) #excluir colunas com nan/valores nulos
    data = data.dropna()
    df = df.append(data)
    #df.to_excel('Tabela.xlsx', index=False)    

df
# Out:
#            SS  OS                       Serviço  \
# 0   972659151   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 1   972958699   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 2   973012085   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 3   973013333   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 4   973087021   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# ..        ...  ..                           ...
# 36  903811664   1  2 - LIG.AGUA DIAM.1/2 C/HID.
# 37  973184594   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 38  973289752   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 39  973284513   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 40  973458121   2  2 - LIG.AGUA DIAM.1/2 C/HID.
#
#                               Equipe              Localidade  \
# 0    308A - ADAILTON PASSOS DE SOUZA  700 - LAURO DE FREITAS
# 1   215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# 2   215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# 3     214-A - CRISTIANO VIANA MACEDO  700 - LAURO DE FREITAS
# 4   215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# ..                               ...                     ...
# 36  215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# 37   216-A - ARIVALDO SOUZA MONTEIRO      900 - SALVADOR UMB
# 38  215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# 39  215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# 40   216-A - ARIVALDO SOUZA MONTEIRO      900 - SALVADOR UMB
#
#               Bairro                                Logradouro  \
# 0    11 - BURAQUINHO  407499 - RU MIN ANTONIO CARLOS MAGALHAES
# 1       1 - IPITANGA            440208 - TV LAGOA DOS PATOS 1A
# 2        13 - ITINGA                 403124 - RU SAO CRISTOVAO
# 3       1 - IPITANGA         401148 - RU CONS MENANDRO MINAHIN
# 4        13 - ITINGA         403396 - RU LOURENCO F DOS SANTOS
# ..               ...                                       ...
# 36       13 - ITINGA                403183 - RU JOANA ANGELICA
# 37  16 - BOCA DO RIO                   68515 - RU DA MACONARIA
# 38  9 - PITANGUEIRAS      400796 - AV BRIG ALBERTO COSTA MATOS
# 39    37 - VIDA NOVA               402829 - RU NILZETE O SOUZA
# 40       18 - ITAPUA          131608 - RU ENCONTRO DAS ARVORES
#
#            Encerramento                                          Obs da SS  \
# 0   28/07/2022 15:10:55  CLIENTE SOLICITA LIGACAO NOVA DE AGUA CIENTE T...
# 1   26/07/2022 09:53:21  DOC EM ANEXO, CLIENTE INFORMA QUE NAO TEM DOC ...
# 2   27/07/2022 10:41:26  CLI SOLIC DESMEMBRAMENTO DA MATRICULA 91582881...
# 3   28/07/2022 17:19:31  CLI SOLIC LIG NOVA CIENTE DE TAXA E PRAZO N IN...
# 4   29/07/2022 15:20:41  SR ITALO APRESENTOU RG E CPF , CONTA DE LUZ E ...
# ..                  ...                                                ...
# 36  03/08/2022 17:13:18  GEO/2022 FAVOR COLOCAR LIGACAO CLANDESTINA DEN...
# 37  05/08/2022 13:44:07  SR.JUCIMAR BISPO DA SILVA COM AUTORIZACAO SOLI...
# 38  08/08/2022 12:51:34  DESMEMBRAMENTO DA MAT 91437440 ;INSCRICAO 0700...
# 39  05/08/2022 17:20:45  CLIENTE APRESENTOU CONTRATO DE COMPRA E VENDA ...
# 40  05/08/2022 15:32:41  PJ 0105040-84.2022.8.05.0001 - LIMINAR URGENTE...
#
#                                      Obs de Enc da OS
# 0                         MATRICULA GERADA: 184848539
# 1                         MATRICULA GERADA: 184836328
# 2                         MATRICULA GERADA: 184842182
# 3                         MATRICULA GERADA: 184849560
# 4                         MATRICULA GERADA: 184853567
# ..                                                ...
# 36  EXECUTADO A ESCAVACAO MECANIZADA NA RUA COM PA...
# 37                        MATRICULA GERADA: 184884454
# 38                        MATRICULA GERADA: 184890071
# 39                        MATRICULA GERADA: 184887100
# 40                        MATRICULA GERADA: 184885892
#
# [143 rows x 10 columns]

# %%
#Modelo de For 1 - listar arquivos em pasta
files_xls = [path + '\\' + f for f in files if f[-3:] =='xls']
print(files_xls)
# Out:
# ['C:\\Users\\gleisson.santos\\Desktop\\2 - Projetos Python\\Projeto #1 - Automção SCIWEB\\Projeto #6 - Extração de dados Selenium e BD\\aa\\AtendimentoeServicos_Consulta_ConsultaGeral (22).xls', 'C:\\Users\\gleisson.santos\\Desktop\\2 - Projetos Python\\Projeto #1 - Automção SCIWEB\\Projeto #6 - Extração de dados Selenium e BD\\aa\\AtendimentoeServicos_Consulta_ConsultaGeral (23).xls', 'C:\\Users\\gleisson.santos\\Desktop\\2 - Projetos Python\\Projeto #1 - Automção SCIWEB\\Projeto #6 - Extração de dados Selenium e BD\\aa\\AtendimentoeServicos_Consulta_ConsultaGeral (24).xls']

# %%
##Modelo de For 2 - Listar arquivos em pasta
for f in files_xls:
    print(f)
# Out:
# C:\Users\gleisson.santos\Desktop\2 - Projetos Python\Projeto #1 - Automção SCIWEB\Projeto #6 - Extração de dados Selenium e BD\aa\AtendimentoeServicos_Consulta_ConsultaGeral (22).xls
# C:\Users\gleisson.santos\Desktop\2 - Projetos Python\Projeto #1 - Automção SCIWEB\Projeto #6 - Extração de dados Selenium e BD\aa\AtendimentoeServicos_Consulta_ConsultaGeral (23).xls
# C:\Users\gleisson.santos\Desktop\2 - Projetos Python\Projeto #1 - Automção SCIWEB\Projeto #6 - Extração de dados Selenium e BD\aa\AtendimentoeServicos_Consulta_ConsultaGeral (24).xls

# %%
#ALTERAR NOME DE COLUNAS
df = df.rename(columns={'Obs da SS': 'ObsOS'})
df = df.rename(columns={'Obs de Enc da OS': 'ObsEnc'})

df
# Out:
#            SS  OS                       Serviço  \
# 0   972659151   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 1   972958699   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 2   973012085   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 3   973013333   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 4   973087021   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# ..        ...  ..                           ...
# 36  903811664   1  2 - LIG.AGUA DIAM.1/2 C/HID.
# 37  973184594   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 38  973289752   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 39  973284513   2  2 - LIG.AGUA DIAM.1/2 C/HID.
# 40  973458121   2  2 - LIG.AGUA DIAM.1/2 C/HID.
#
#                               Equipe              Localidade  \
# 0    308A - ADAILTON PASSOS DE SOUZA  700 - LAURO DE FREITAS
# 1   215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# 2   215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# 3     214-A - CRISTIANO VIANA MACEDO  700 - LAURO DE FREITAS
# 4   215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# ..                               ...                     ...
# 36  215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# 37   216-A - ARIVALDO SOUZA MONTEIRO      900 - SALVADOR UMB
# 38  215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# 39  215-A - NARCISO CONCEICAO FRANCA  700 - LAURO DE FREITAS
# 40   216-A - ARIVALDO SOUZA MONTEIRO      900 - SALVADOR UMB
#
#               Bairro                                Logradouro  \
# 0    11 - BURAQUINHO  407499 - RU MIN ANTONIO CARLOS MAGALHAES
# 1       1 - IPITANGA            440208 - TV LAGOA DOS PATOS 1A
# 2        13 - ITINGA                 403124 - RU SAO CRISTOVAO
# 3       1 - IPITANGA         401148 - RU CONS MENANDRO MINAHIN
# 4        13 - ITINGA         403396 - RU LOURENCO F DOS SANTOS
# ..               ...                                       ...
# 36       13 - ITINGA                403183 - RU JOANA ANGELICA
# 37  16 - BOCA DO RIO                   68515 - RU DA MACONARIA
# 38  9 - PITANGUEIRAS      400796 - AV BRIG ALBERTO COSTA MATOS
# 39    37 - VIDA NOVA               402829 - RU NILZETE O SOUZA
# 40       18 - ITAPUA          131608 - RU ENCONTRO DAS ARVORES
#
#            Encerramento                                              ObsOS  \
# 0   28/07/2022 15:10:55  CLIENTE SOLICITA LIGACAO NOVA DE AGUA CIENTE T...
# 1   26/07/2022 09:53:21  DOC EM ANEXO, CLIENTE INFORMA QUE NAO TEM DOC ...
# 2   27/07/2022 10:41:26  CLI SOLIC DESMEMBRAMENTO DA MATRICULA 91582881...
# 3   28/07/2022 17:19:31  CLI SOLIC LIG NOVA CIENTE DE TAXA E PRAZO N IN...
# 4   29/07/2022 15:20:41  SR ITALO APRESENTOU RG E CPF , CONTA DE LUZ E ...
# ..                  ...                                                ...
# 36  03/08/2022 17:13:18  GEO/2022 FAVOR COLOCAR LIGACAO CLANDESTINA DEN...
# 37  05/08/2022 13:44:07  SR.JUCIMAR BISPO DA SILVA COM AUTORIZACAO SOLI...
# 38  08/08/2022 12:51:34  DESMEMBRAMENTO DA MAT 91437440 ;INSCRICAO 0700...
# 39  05/08/2022 17:20:45  CLIENTE APRESENTOU CONTRATO DE COMPRA E VENDA ...
# 40  05/08/2022 15:32:41  PJ 0105040-84.2022.8.05.0001 - LIMINAR URGENTE...
#
#                                                ObsEnc
# 0                         MATRICULA GERADA: 184848539
# 1                         MATRICULA GERADA: 184836328
# 2                         MATRICULA GERADA: 184842182
# 3                         MATRICULA GERADA: 184849560
# 4                         MATRICULA GERADA: 184853567
# ..                                                ...
# 36  EXECUTADO A ESCAVACAO MECANIZADA NA RUA COM PA...
# 37                        MATRICULA GERADA: 184884454
# 38                        MATRICULA GERADA: 184890071
# 39                        MATRICULA GERADA: 184887100
# 40                        MATRICULA GERADA: 184885892
#
# [66 rows x 10 columns]

# %%
#FUNÇAO PARA CONEXAO COM O BANCO DE DADOS SQL
def executar_conexao():
    server = 'TBDBL-GLEISSON'
    database = 'Dados_Pavimento'
    username = 'gleisson.santos'
    password = '1234'
    conexao = pyodbc.connect(
        'DRIVER={SQL Server};SERVER=' + server + ';DATABASE=' + database + ';UID=' + username + ';PWD=' + password)
    print('Conexão Ok')
    return conexao
executar_conexao()
# Out:
# Conexão Ok

# %%
#VIEW DE LINHAS
for index, row in df.iterrows():
    print(row.Equipe)
# Out:
# 308A - ADAILTON PASSOS DE SOUZA
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 214-A - CRISTIANO VIANA MACEDO
# 215-A - NARCISO CONCEICAO FRANCA
# 320A - CELIO ROBERTO DE JESUS
# 320A - CELIO ROBERTO DE JESUS
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 221-A - EDCARLOS CARVALHO ALMEIDA
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 320A - CELIO ROBERTO DE JESUS
# 320A - CELIO ROBERTO DE JESUS
# 221-A - EDCARLOS CARVALHO ALMEIDA
# 221-A - EDCARLOS CARVALHO ALMEIDA
# 214-A - CRISTIANO VIANA MACEDO
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 308A - ADAILTON PASSOS DE SOUZA
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 102-A - ERICO MOTA RIBEIRO
# 216-A - ARIVALDO SOUZA MONTEIRO
# 214-A - CRISTIANO VIANA MACEDO
# 215-A - NARCISO CONCEICAO FRANCA
# 320A - CELIO ROBERTO DE JESUS
# 320A - CELIO ROBERTO DE JESUS
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 221-A - EDCARLOS CARVALHO ALMEIDA
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 216-A - ARIVALDO SOUZA MONTEIRO
# 216-A - ARIVALDO SOUZA MONTEIRO
# 225-A - EDLON DOS SANTOS GUEDES
# 225-A - EDLON DOS SANTOS GUEDES
# 313A - JOSE CARLOS DE ANUNCIACAO
# 320A - CELIO ROBERTO DE JESUS
# 320A - CELIO ROBERTO DE JESUS
# 221-A - EDCARLOS CARVALHO ALMEIDA
# 221-A - EDCARLOS CARVALHO ALMEIDA
# 225-A - EDLON DOS SANTOS GUEDES
# 214-A - CRISTIANO VIANA MACEDO
# 216-A - ARIVALDO SOUZA MONTEIRO
# 225-A - EDLON DOS SANTOS GUEDES
# 215-A - NARCISO CONCEICAO FRANCA
# 225-A - EDLON DOS SANTOS GUEDES
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 216-A - ARIVALDO SOUZA MONTEIRO
# 215-A - NARCISO CONCEICAO FRANCA
# 216-A - ARIVALDO SOUZA MONTEIRO
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 216-A - ARIVALDO SOUZA MONTEIRO
# 215-A - NARCISO CONCEICAO FRANCA
# 215-A - NARCISO CONCEICAO FRANCA
# 216-A - ARIVALDO SOUZA MONTEIRO

# %%
#INSERT DA TABALA TRATADA AO BANCO DE DADOS SQL
cursor = executar_conexao().cursor()
for index, row in df.iterrows():
    cursor.execute("INSERT INTO Material (SS, OS, Serviço, Equipe, Localidade, Bairro, Logradouro, Encerramento, ObsOS) values(?,?,?,?,?,?,?,?,?)",
                row.SS, row.OS, row.Serviço, row.Equipe, row.Localidade,  row.Bairro, row.Logradouro, row.Encerramento, row.ObsOS)

cursor.commit()
cursor.close()
# Out:
# Conexão Ok

# %%
#INSERT DA TABALA TRATADA AO BANCO DE DADOS SQL
cursor = executar_conexao().cursor()
for index, row in df.iterrows():
    cursor.execute("INSERT INTO Material (SS, OS, Serviço, Equipe, Localidade, Bairro, Logradouro, Encerramento, ObsOS) values(?,?,?,?,?,?,?,?,?)",
                row.SS, row.OS, row.Serviço, row.Equipe, row.Localidade,  row.Bairro, row.Logradouro, row.Encerramento, row.ObsOS)

cursor.commit()
cursor.close()

# %%
#APAGAR REGISTROS NA TABELA
cursor = executar_conexao().cursor()
cursor.execute('TRUNCATE TABLE Material')
cursor.commit()
# Out:
# Conexão Ok

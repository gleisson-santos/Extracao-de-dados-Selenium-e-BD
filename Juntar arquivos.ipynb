# %%
#IMPORTAÇÃO DOS MODULOS E CHAMADA DAS TABELAS
import os
import pandas as pd
import glob
import pyodbc

#FUNÇAO PARA CONEXAO COM O BANCO DE DADOS SQL
def executar_conexao():
    server = 'TBDBL-GLEISSON'
    database = 'Dados_Pavimento'
    username = 'gleisson.santos'
    password = '12345'
    conexao = pyodbc.connect(
        'DRIVER={SQL Server};SERVER=' + server + ';DATABASE=' + database + ';UID=' + username + ';PWD=' + password)
    print('Conexão ao BD realizada com Socesso!')
    return conexao
executar_conexao()
# Out:
# Conexão ao BD realizada com Socesso!

# %%
path = r'C:\Users\gleisson.santos\Desktop\Projetos Checkd Git\# 1 Extração e Automação de dados\Extração da dados\Extração de dados Selenium e BD\Extracao-de-dados-Selenium-e-BD\aa'
files_xls = os.listdir(path)

df = pd.DataFrame()
for f in files_xls:
    file_path = os.path.join(path, f)
    data = pd.read_html(file_path)
    data = data[1]
    data = data.dropna(axis=1, how='all')
    df = df.append(data)   
df
#df.to_excel('Dados.xlsx', index=False)
# Out:
#              SS  OS                               Tipo  \
# 0     974266250   2      26 - MANUTENCAO DE HIDROMETRO
# 1     974266261   2      26 - MANUTENCAO DE HIDROMETRO
# 2     974266445   2      26 - MANUTENCAO DE HIDROMETRO
# 3     974266448   2      26 - MANUTENCAO DE HIDROMETRO
# 4     974056343   2      26 - MANUTENCAO DE HIDROMETRO
# ...         ...  ..                                ...
# 2065  981153745   1          25 - MANUTENCAO DE ESGOTO
# 2066  981153900   1  45 - VERIFICACAO DE FALTA DE AGUA
# 2067  981153906   1             43 - VAZAMENTO DE AGUA
# 2068  981154094   1             43 - VAZAMENTO DE AGUA
# 2069  981154162   1             43 - VAZAMENTO DE AGUA
#
#                                 Especificação  \
# 0              19 - REVISAO HIDROMETRO PARADO
# 1              19 - REVISAO HIDROMETRO PARADO
# 2              19 - REVISAO HIDROMETRO PARADO
# 3              19 - REVISAO HIDROMETRO PARADO
# 4                2 - INSTALACAO DE HIDROMETRO
# ...                                       ...
# 2065  2 - EXTRAVASAMENTO DE ESGOTO RAMAL - CI
# 2066              1 - FALTA DE AGUA NO IMOVEL
# 2067              3 - VAZAMENTO NO HIDROMETRO
# 2068              3 - VAZAMENTO NO HIDROMETRO
# 2069              3 - VAZAMENTO NO HIDROMETRO
#
#                               Serviço                       Unid Atual (OS)  \
# 0              12 - SUBSTITUICAO HID.  88880068 - CONSORCIO NOVA BOLANDEIRA
# 1              12 - SUBSTITUICAO HID.  88880068 - CONSORCIO NOVA BOLANDEIRA
# 2              12 - SUBSTITUICAO HID.  88880068 - CONSORCIO NOVA BOLANDEIRA
# 3              12 - SUBSTITUICAO HID.  88880068 - CONSORCIO NOVA BOLANDEIRA
# 4          11 - INSTALACAO DE HIDROM.  88880068 - CONSORCIO NOVA BOLANDEIRA
# ...                               ...                                   ...
# 2065  438 - DES RED ESG E PVS C/EQUIP  88880068 - CONSORCIO NOVA BOLANDEIRA
# 2066    364 - VERIF FALTA AGUA IMOVEL  88880068 - CONSORCIO NOVA BOLANDEIRA
# 2067    290 - VAZAMENTO NO HIDROMETRO  88880068 - CONSORCIO NOVA BOLANDEIRA
# 2068    290 - VAZAMENTO NO HIDROMETRO  88880068 - CONSORCIO NOVA BOLANDEIRA
# 2069    290 - VAZAMENTO NO HIDROMETRO  88880068 - CONSORCIO NOVA BOLANDEIRA
#
#                                  Equipe Origem da SS              Localidade  \
# 0       216-A - ARIVALDO SOUZA MONTEIRO      Interna      900 - SALVADOR UMB
# 1       216-A - ARIVALDO SOUZA MONTEIRO      Interna      900 - SALVADOR UMB
# 2       216-A - ARIVALDO SOUZA MONTEIRO      Interna      900 - SALVADOR UMB
# 3       216-A - ARIVALDO SOUZA MONTEIRO      Interna      900 - SALVADOR UMB
# 4            327-A - ELZITO SOUZA NUNES      Interna      900 - SALVADOR UMB
# ...                                 ...          ...                     ...
# 2065    222E - GILVANDO DE SOUZA SANTOS      Cliente  700 - LAURO DE FREITAS
# 2066         102-A - ERICO MOTA RIBEIRO      Cliente      900 - SALVADOR UMB
# 2067  210A - JOSEILTON JESUS DOS SANTOS      Cliente  700 - LAURO DE FREITAS
# 2068         102-A - ERICO MOTA RIBEIRO      Cliente      900 - SALVADOR UMB
# 2069    143-A - YAN QUARESMA DOS SANTOS      Cliente      900 - SALVADOR UMB
#
#                    Bairro  ...       Ini do Serviço       Fim do Serviço  \
# 0          233 - CASSANGE  ...                  NaN                  NaN
# 1          233 - CASSANGE  ...  16/02/2023 10:10:00  16/02/2023 10:21:00
# 2          233 - CASSANGE  ...  16/02/2023 10:34:00  16/02/2023 11:07:00
# 3          233 - CASSANGE  ...                  NaN                  NaN
# 4     191 - BAIRRO DA PAZ  ...                  NaN                  NaN
# ...                   ...  ...                  ...                  ...
# 2065          10 - CENTRO  ...  25/02/2023 15:50:00  25/02/2023 16:15:00
# 2066   64 - SAO CRISTOVAO  ...  25/02/2023 17:02:00  25/02/2023 17:04:00
# 2067          10 - CENTRO  ...  25/02/2023 16:00:00  25/02/2023 16:38:00
# 2068     119 - MUSSURUNGA  ...  25/02/2023 17:58:00  25/02/2023 18:04:00
# 2069          18 - ITAPUA  ...  25/02/2023 16:49:00  25/02/2023 16:56:00
#
#              Encerramento               Mot de Encerr da OS  \
# 0     17/02/2023 09:37:57  102 - LIGACAO ENCONTRADA CORTADA
# 1     17/02/2023 09:34:54                 0 - NAO INFORMADO
# 2     17/02/2023 09:31:48                 0 - NAO INFORMADO
# 3     17/02/2023 09:36:48        11 - IMOVEL NAO LOCALIZADO
# 4     16/02/2023 14:12:26    8 - NAO PERMITIDO PELO USUARIO
# ...                   ...                               ...
# 2065  25/02/2023 16:21:45                       160 - BUCHA
# 2066  25/02/2023 17:05:19                 0 - NAO INFORMADO
# 2067  25/02/2023 16:44:24                 0 - NAO INFORMADO
# 2068  25/02/2023 18:05:12                 0 - NAO INFORMADO
# 2069  25/02/2023 17:02:00                 0 - NAO INFORMADO
#
#                     Sit da OS Insumos                  Func. Encerrou OS  \
# 0     Concluída Não Executada       0  200112 - OSMARIO DOS SANTOS MOURA
# 1         Concluída Executada       2  200112 - OSMARIO DOS SANTOS MOURA
# 2         Concluída Executada       2  200112 - OSMARIO DOS SANTOS MOURA
# 3     Concluída Não Executada       0  200112 - OSMARIO DOS SANTOS MOURA
# 4     Concluída Não Executada       0  200112 - OSMARIO DOS SANTOS MOURA
# ...                       ...     ...                                ...
# 2065      Concluída Executada       0  204589 - GLEISSON DE JESUS SANTOS
# 2066      Concluída Executada       0       900032 - INTEGRACAO DIGITEAM
# 2067      Concluída Executada       0  204589 - GLEISSON DE JESUS SANTOS
# 2068      Concluída Executada       3       900032 - INTEGRACAO DIGITEAM
# 2069      Concluída Executada       3       900032 - INTEGRACAO DIGITEAM
#
#      SS Atendida Tipo de Operação Data/Hora Última Tramitação da OS
# 0            Não        Comercial               03/10/2022 17:29:33
# 1            Sim        Comercial               03/10/2022 17:29:42
# 2            Sim        Comercial               04/10/2022 17:24:56
# 3            Não        Comercial               04/10/2022 17:24:56
# 4            Não        Comercial               09/09/2022 15:51:58
# ...          ...              ...                               ...
# 2065         Sim           Esgoto               25/02/2023 15:30:28
# 2066         Sim             Água               25/02/2023 15:51:03
# 2067         Sim             Água               25/02/2023 15:54:33
# 2068         Sim             Água               25/02/2023 16:07:35
# 2069         Sim             Água               25/02/2023 16:18:57
#
# [4466 rows x 21 columns]

# %%
#INSERT DA TABALA TRATADA AO BANCO DE DADOS SQL
cursor = executar_conexao().cursor()
for index, row in df.iterrows():
    cursor.execute("INSERT INTO Material (SS, OS, Serviço, Equipe, Localidade, Bairro, Logradouro, Encerramento, ObsOS, ObsEnc) values(?,?,?,?,?,?,?,?,?,?)",
                row.SS, row.OS, row.Serviço, row.Equipe, row.Localidade,  row.Bairro, row.Logradouro, row.Encerramento, row.ObsOS, row.ObsEnc)

cursor.commit()
cursor.close()
# Out:
# Conexão Ok
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# C:\Users\GLEISS~1.SAN\AppData\Local\Temp/ipykernel_14376/4258093957.py in <module>
#       2 cursor = executar_conexao().cursor()
#       3 for index, row in df.iterrows():
# ----> 4     cursor.execute("INSERT INTO Material (SS, OS, Serviço, Equipe, Localidade, Bairro, Logradouro, Encerramento, ObsOS, ObsEnc) values(?,?,?,?,?,?,?,?,?,?)",
#       5                 row.SS, row.OS, row.Serviço, row.Equipe, row.Localidade,  row.Bairro, row.Logradouro, row.Encerramento, row.ObsOS, row.ObsEnc)
#       6
#
# ProgrammingError: ('42000', '[42000] [Microsoft][ODBC SQL Server Driver][SQL Server]O fluxo de protocolo da chamada de procedimento remoto (RPC) do protocolo TDS recebido está incorreto. Parâmetro 13 (""): o valor fornecido não é uma instância válida do tipo de dados float. Procure valores inválidos nos dados de origem. Dados do tipo numérico com escala maior que precisão são um exemplo de um valor inválido. (8023) (SQLExecDirectW)')

# %%
#APAGAR REGISTROS NA TABELA
cursor = executar_conexao().cursor()
cursor.execute('TRUNCATE TABLE Material')
cursor.commit()
# Out:
# Conexão Ok
